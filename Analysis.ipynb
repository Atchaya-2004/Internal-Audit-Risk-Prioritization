# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Internal audit dataset.xlsx")

# %%
df.head()
# Out:
#   BranchID                    BranchName        City       BranchType  \
# 0    BR001    Hyderabad - Forex/Treasury   Hyderabad   Forex/Treasury
# 1    BR002             Pune - HR & Admin        Pune       HR & Admin
# 2    BR003     Bangalore - Retail Branch   Bangalore    Retail Branch
# 3    BR004   Coimbatore - Loans & Credit  Coimbatore   Loans & Credit
# 4    BR005  Coimbatore - Digital Banking  Coimbatore  Digital Banking
#
#    DaysSinceLastAudit  PastFindingsCount  TransactionVolumeCr  \
# 0                 424                  0                96.39
# 1                 204                  0                15.40
# 2                 785                  0                19.57
# 3                 180                  1                18.33
# 4                 381                  2                 6.09
#
#   RegulatorySensitivity  StaffCount  StaffTurnoverRate  ComplaintsLastYear  \
# 0                  High          31               23.5                   0
# ...

# %%
df.shape
# Out:
# (50, 13)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   BranchID                 50 non-null     str
#  1   BranchName               50 non-null     str
#  2   City                     50 non-null     str
#  3   BranchType               50 non-null     str
#  4   DaysSinceLastAudit       50 non-null     int64
#  5   PastFindingsCount        50 non-null     int64
#  6   TransactionVolumeCr      50 non-null     float64
#  7   RegulatorySensitivity    50 non-null     str
#  8   StaffCount               50 non-null     int64
#  9   StaffTurnoverRate        50 non-null     float64
#  10  ComplaintsLastYear       50 non-null     int64
#  11  EstimatedRiskExposureCr  50 non-null     int64
#  12  EstimatedAuditHours      50 non-null     int64
# dtypes: float64(2), int64(6), str(5)
# memory usage: 5.2 KB

# %%
# =====================================
# Step 6: Check Missing Values
# =====================================

df.isnull().sum()
# Out:
# BranchID                   0
# BranchName                 0
# City                       0
# BranchType                 0
# DaysSinceLastAudit         0
# PastFindingsCount          0
# TransactionVolumeCr        0
# RegulatorySensitivity      0
# StaffCount                 0
# StaffTurnoverRate          0
# ComplaintsLastYear         0
# EstimatedRiskExposureCr    0
# EstimatedAuditHours        0
# dtype: int64

# %%
# =====================================
# Step 7: Check Duplicate Rows
# =====================================

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# =====================================
# Step 8: Statistical Summary
# =====================================

df.describe()
# Out:
#        DaysSinceLastAudit  PastFindingsCount  TransactionVolumeCr  StaffCount  \
# count           50.000000          50.000000            50.000000   50.000000
# mean           391.700000           1.440000            39.292600   45.280000
# std            242.971927           1.630826            34.610514   20.912881
# min             65.000000           0.000000             5.040000    8.000000
# 25%            204.000000           0.000000            14.915000   30.250000
# 50%            368.000000           1.000000            29.445000   47.500000
# 75%            486.750000           2.000000            52.962500   63.250000
# max           1112.000000           5.000000           159.490000   79.000000
#
#        StaffTurnoverRate  ComplaintsLastYear  EstimatedRiskExposureCr  \
# count          50.000000           50.000000                50.000000
# mean           19.164000            0.560000                86.560000
# ...

# %%
# =====================================
# Step 9: Unique Branch Types
# =====================================

df["BranchType"].unique()
# Out:
# <StringArray>
# [   'Forex/Treasury',        'HR & Admin',     'Retail Branch',
#     'Loans & Credit',   'Digital Banking', 'Corporate Banking',
#  'Wealth Management',        'Compliance',     'IT Operations']
# Length: 9, dtype: str

# %%
# =====================================
# Step 10: Unique Regulatory Sensitivity
# =====================================

df["RegulatorySensitivity"].unique()
# Out:
# <StringArray>
# ['High', 'Low', 'Medium']
# Length: 3, dtype: str

# %%
# =====================================
# Step 11: Branch Type Count
# =====================================

df["BranchType"].value_counts()
# Out:
# BranchType
# Retail Branch        17
# Loans & Credit        8
# Corporate Banking     6
# Digital Banking       5
# Wealth Management     5
# Forex/Treasury        3
# HR & Admin            3
# IT Operations         2
# Compliance            1
# Name: count, dtype: int64

# %%
# =====================================
# Step 12: Regulatory Sensitivity Count
# =====================================

df["RegulatorySensitivity"].value_counts()
# Out:
# RegulatorySensitivity
# Medium    18
# Low       17
# High      15
# Name: count, dtype: int64

# %%
# =====================================
# Step 13: Number of Branches by City
# =====================================

df["City"].value_counts()
# Out:
# City
# Coimbatore     7
# Chennai        7
# Tirunelveli    5
# Hyderabad      4
# Pune           4
# Bangalore      4
# Madurai        4
# Thanjavur      3
# Erode          2
# Mumbai         2
# Trichy         2
# Vellore        2
# Salem          2
# Delhi          1
# Nagercoil      1
# Name: count, dtype: int64

# %%
# =====================================
# Step 14: Average Transaction Volume by Branch Type
# =====================================

df.groupby("BranchType")["TransactionVolumeCr"].mean()
# Out:
# BranchType
# Compliance           26.910000
# Corporate Banking    50.385000
# Digital Banking      21.334000
# Forex/Treasury       56.603333
# HR & Admin           19.226667
# IT Operations        41.380000
# Loans & Credit       28.705000
# Retail Branch        43.649412
# Wealth Management    49.362000
# Name: TransactionVolumeCr, dtype: float64

# %%
# =====================================
# Step 15: Average Days Since Last Audit
# =====================================

df.groupby("BranchType")["DaysSinceLastAudit"].mean()
# Out:
# BranchType
# Compliance           497.000000
# Corporate Banking    300.666667
# Digital Banking      339.600000
# Forex/Treasury       403.333333
# HR & Admin           195.333333
# IT Operations        597.000000
# Loans & Credit       292.250000
# Retail Branch        537.294118
# Wealth Management    224.800000
# Name: DaysSinceLastAudit, dtype: float64

# %%
# =====================================
# Step 15: Average Days Since Last Audit
# =====================================

df.groupby("BranchType")["DaysSinceLastAudit"].mean()
# Out:
# BranchType
# Compliance           497.000000
# Corporate Banking    300.666667
# Digital Banking      339.600000
# Forex/Treasury       403.333333
# HR & Admin           195.333333
# IT Operations        597.000000
# Loans & Credit       292.250000
# Retail Branch        537.294118
# Wealth Management    224.800000
# Name: DaysSinceLastAudit, dtype: float64

# %%
# =====================================
# Step 17: Total Complaints
# =====================================

df.groupby("BranchType")["ComplaintsLastYear"].sum()
# Out:
# BranchType
# Compliance           1
# Corporate Banking    5
# Digital Banking      1
# Forex/Treasury       1
# HR & Admin           1
# IT Operations        1
# Loans & Credit       8
# Retail Branch        9
# Wealth Management    1
# Name: ComplaintsLastYear, dtype: int64

# %%
# =====================================
# Step 18: Top 10 Branches by Transaction Volume
# =====================================

df.nlargest(10, "TransactionVolumeCr")
# Out:
#    BranchID                     BranchName        City         BranchType  \
# 28    BR029  Bangalore - Corporate Banking   Bangalore  Corporate Banking
# 17    BR018        Vellore - Retail Branch     Vellore      Retail Branch
# 35    BR036      Erode - Wealth Management       Erode  Wealth Management
# 0     BR001     Hyderabad - Forex/Treasury   Hyderabad     Forex/Treasury
# 31    BR032     Coimbatore - Retail Branch  Coimbatore      Retail Branch
# 22    BR023  Thanjavur - Corporate Banking   Thanjavur  Corporate Banking
# 27    BR028      Hyderabad - Retail Branch   Hyderabad      Retail Branch
# 29    BR030        Madurai - Retail Branch     Madurai      Retail Branch
# 6     BR007          Erode - Retail Branch       Erode      Retail Branch
# 46    BR047        Chennai - IT Operations     Chennai      IT Operations
#
#     DaysSinceLastAudit  PastFindingsCount  TransactionVolumeCr  \
# 28                 248                  2               159.49
# ...

# %%
df.sort_values(by="TransactionVolumeCr", ascending=False).head(10)
# Out:
#    BranchID                     BranchName        City         BranchType  \
# 28    BR029  Bangalore - Corporate Banking   Bangalore  Corporate Banking
# 17    BR018        Vellore - Retail Branch     Vellore      Retail Branch
# 35    BR036      Erode - Wealth Management       Erode  Wealth Management
# 0     BR001     Hyderabad - Forex/Treasury   Hyderabad     Forex/Treasury
# 31    BR032     Coimbatore - Retail Branch  Coimbatore      Retail Branch
# 22    BR023  Thanjavur - Corporate Banking   Thanjavur  Corporate Banking
# 27    BR028      Hyderabad - Retail Branch   Hyderabad      Retail Branch
# 29    BR030        Madurai - Retail Branch     Madurai      Retail Branch
# 6     BR007          Erode - Retail Branch       Erode      Retail Branch
# 46    BR047        Chennai - IT Operations     Chennai      IT Operations
#
#     DaysSinceLastAudit  PastFindingsCount  TransactionVolumeCr  \
# 28                 248                  2               159.49
# ...

# %%
# =====================================
# Step 19: Longest Time Since Last Audit
# =====================================

df.nlargest(10, "DaysSinceLastAudit")
# Out:
#    BranchID                     BranchName         City         BranchType  \
# 27    BR028      Hyderabad - Retail Branch    Hyderabad      Retail Branch
# 11    BR012         Mumbai - Retail Branch       Mumbai      Retail Branch
# 49    BR050    Tirunelveli - Retail Branch  Tirunelveli      Retail Branch
# 47    BR048     Coimbatore - Retail Branch   Coimbatore      Retail Branch
# 46    BR047        Chennai - IT Operations      Chennai      IT Operations
# 2     BR003      Bangalore - Retail Branch    Bangalore      Retail Branch
# 33    BR034       Madurai - Loans & Credit      Madurai     Loans & Credit
# 7     BR008    Tirunelveli - Retail Branch  Tirunelveli      Retail Branch
# 22    BR023  Thanjavur - Corporate Banking    Thanjavur  Corporate Banking
# 36    BR037          Salem - Retail Branch        Salem      Retail Branch
#
#     DaysSinceLastAudit  PastFindingsCount  TransactionVolumeCr  \
# 27                1112                  0                68.89
# ...

# %%
# =====================================
# Step 20: Highest Past Audit Findings
# =====================================

df.nlargest(10, "PastFindingsCount")
# Out:
#    BranchID                       BranchName         City         BranchType  \
# 22    BR023    Thanjavur - Corporate Banking    Thanjavur  Corporate Banking
# 33    BR034         Madurai - Loans & Credit      Madurai     Loans & Credit
# 35    BR036        Erode - Wealth Management        Erode  Wealth Management
# 44    BR045         Chennai - Forex/Treasury      Chennai     Forex/Treasury
# 9     BR010          Delhi - Digital Banking        Delhi    Digital Banking
# 20    BR021         Chennai - Loans & Credit      Chennai     Loans & Credit
# 34    BR035      Madurai - Corporate Banking      Madurai  Corporate Banking
# 42    BR043       Trichy - Corporate Banking       Trichy  Corporate Banking
# 13    BR014     Tirunelveli - Loans & Credit  Tirunelveli     Loans & Credit
# 25    BR026  Tirunelveli - Wealth Management  Tirunelveli  Wealth Management
#
#     DaysSinceLastAudit  PastFindingsCount  TransactionVolumeCr  \
# ...

# %%
# =====================================
# Step 21: Highest Customer Complaints
# =====================================

df.nlargest(10, "ComplaintsLastYear")
# Out:
#    BranchID                     BranchName         City         BranchType  \
# 16    BR017    Coimbatore - Loans & Credit   Coimbatore     Loans & Credit
# 10    BR011       Pune - Corporate Banking         Pune  Corporate Banking
# 28    BR029  Bangalore - Corporate Banking    Bangalore  Corporate Banking
# 2     BR003      Bangalore - Retail Branch    Bangalore      Retail Branch
# 3     BR004    Coimbatore - Loans & Credit   Coimbatore     Loans & Credit
# 6     BR007          Erode - Retail Branch        Erode      Retail Branch
# 7     BR008    Tirunelveli - Retail Branch  Tirunelveli      Retail Branch
# 8     BR009       Tirunelveli - HR & Admin  Tirunelveli         HR & Admin
# 9     BR010        Delhi - Digital Banking        Delhi    Digital Banking
# 13    BR014   Tirunelveli - Loans & Credit  Tirunelveli     Loans & Credit
#
#     DaysSinceLastAudit  PastFindingsCount  TransactionVolumeCr  \
# 16                 314                  0                40.51
# ...

# %%
# =====================================
# Step 22: Convert Regulatory Sensitivity to Numeric
# =====================================

regulatory_map = {
    "Low": 1,
    "Medium": 2,
    "High": 3
}

df["RegulatoryScore"] = df["RegulatorySensitivity"].map(regulatory_map)

# %%
df.head()
# Out:
#   BranchID                    BranchName        City       BranchType  \
# 0    BR001    Hyderabad - Forex/Treasury   Hyderabad   Forex/Treasury
# 1    BR002             Pune - HR & Admin        Pune       HR & Admin
# 2    BR003     Bangalore - Retail Branch   Bangalore    Retail Branch
# 3    BR004   Coimbatore - Loans & Credit  Coimbatore   Loans & Credit
# 4    BR005  Coimbatore - Digital Banking  Coimbatore  Digital Banking
#
#    DaysSinceLastAudit  PastFindingsCount  TransactionVolumeCr  \
# 0                 424                  0                96.39
# 1                 204                  0                15.40
# 2                 785                  0                19.57
# 3                 180                  1                18.33
# 4                 381                  2                 6.09
#
#   RegulatorySensitivity  StaffCount  StaffTurnoverRate  ComplaintsLastYear  \
# 0                  High          31               23.5                   0
# ...

# %%
# =====================================
# Step 24: Normalize Risk Factors
# =====================================

columns_to_scale = [
    "DaysSinceLastAudit",
    "PastFindingsCount",
    "TransactionVolumeCr",
    "StaffTurnoverRate",
    "ComplaintsLastYear"
]

for col in columns_to_scale:
    df[col + "_Scaled"] = (
        (df[col] - df[col].min()) /
        (df[col].max() - df[col].min())
    )

# %%
# Normalize Regulatory Score

df["RegulatoryScore_Scaled"] = (
    (df["RegulatoryScore"] - df["RegulatoryScore"].min()) /
    (df["RegulatoryScore"].max() - df["RegulatoryScore"].min())
)

# %%
df.head()
# Out:
#   BranchID                    BranchName        City       BranchType  \
# 0    BR001    Hyderabad - Forex/Treasury   Hyderabad   Forex/Treasury
# 1    BR002             Pune - HR & Admin        Pune       HR & Admin
# 2    BR003     Bangalore - Retail Branch   Bangalore    Retail Branch
# 3    BR004   Coimbatore - Loans & Credit  Coimbatore   Loans & Credit
# 4    BR005  Coimbatore - Digital Banking  Coimbatore  Digital Banking
#
#    DaysSinceLastAudit  PastFindingsCount  TransactionVolumeCr  \
# 0                 424                  0                96.39
# 1                 204                  0                15.40
# 2                 785                  0                19.57
# 3                 180                  1                18.33
# 4                 381                  2                 6.09
#
#   RegulatorySensitivity  StaffCount  StaffTurnoverRate  ComplaintsLastYear  \
# 0                  High          31               23.5                   0
# ...

# %%
df["RiskScore"] = (
    df["DaysSinceLastAudit_Scaled"] * 0.30 +
    df["PastFindingsCount_Scaled"] * 0.25 +
    df["TransactionVolumeCr_Scaled"] * 0.20 +
    df["RegulatoryScore_Scaled"] * 0.15 +
    df["StaffTurnoverRate_Scaled"] * 0.05 +
    df["ComplaintsLastYear_Scaled"] * 0.05
)

# %%
df[["BranchID","BranchName","RiskScore"]].head()
# Out:
#   BranchID                    BranchName  RiskScore
# 0    BR001    Hyderabad - Forex/Treasury   0.404022
# 1    BR002             Pune - HR & Admin   0.079567
# 2    BR003     Bangalore - Retail Branch   0.265150
# 3    BR004   Coimbatore - Loans & Credit   0.192918
# 4    BR005  Coimbatore - Digital Banking   0.303664

# %%
# =====================================
# Step 28: Rank Branches by Risk Score
# =====================================

df["RiskRank"] = df["RiskScore"].rank(method="dense", ascending=False)

# %%
# =====================================
# Step 29: Audit Selection
# =====================================

df["AuditDecision"] = np.where(
    df["RiskRank"] <= 20,
    "Selected for Audit",
    "Deferred"
)

# %%
# =====================================
# Step 30: Risk Tier
# =====================================

def risk_tier(score):
    if score >= 0.50:
        return "High"
    elif score >= 0.40:
        return "Medium"
    else:
        return "Low"

df["RiskTier"] = df["RiskScore"].apply(risk_tier)

# %%
# =====================================
# Step 31: Risk Tier Distribution
# =====================================

df["RiskTier"].value_counts()
# Out:
# RiskTier
# Low       35
# Medium     8
# High       7
# Name: count, dtype: int64

# %%
# =====================================
# Step 32: Audit Decision Count
# =====================================

df["AuditDecision"].value_counts()
# Out:
# AuditDecision
# Deferred              30
# Selected for Audit    20
# Name: count, dtype: int64

# %%
# =====================================
# Step 33: Top 20 Branches
# =====================================

df.sort_values("RiskRank").head(20)
# Out:
#    BranchID                     BranchName         City         BranchType  \
# 22    BR023  Thanjavur - Corporate Banking    Thanjavur  Corporate Banking
# 33    BR034       Madurai - Loans & Credit      Madurai     Loans & Credit
# 35    BR036      Erode - Wealth Management        Erode  Wealth Management
# 44    BR045       Chennai - Forex/Treasury      Chennai     Forex/Treasury
# 17    BR018        Vellore - Retail Branch      Vellore      Retail Branch
# 28    BR029  Bangalore - Corporate Banking    Bangalore  Corporate Banking
# 20    BR021       Chennai - Loans & Credit      Chennai     Loans & Credit
# 9     BR010        Delhi - Digital Banking        Delhi    Digital Banking
# 13    BR014   Tirunelveli - Loans & Credit  Tirunelveli     Loans & Credit
# 42    BR043     Trichy - Corporate Banking       Trichy  Corporate Banking
# 34    BR035    Madurai - Corporate Banking      Madurai  Corporate Banking
# ...

# %%
# =====================================
# Step 34: Export Final Dataset
# =====================================

df.to_csv("Internal_Audit_Final.csv", index=False)

print("Final dataset exported successfully!")
# Out:
# Final dataset exported successfully!

# %%
# =====================================
# Step 31: Final Result
# =====================================

df[[
    "BranchID",
    "BranchName",
    "RiskScore",
    "RiskRank",
    "RiskTier",
    "AuditDecision"
]].sort_values(by="RiskRank").head(20)
# Out:
#    BranchID                     BranchName  RiskScore  RiskRank RiskTier  \
# 22    BR023  Thanjavur - Corporate Banking   0.677535       1.0     High
# 33    BR034       Madurai - Loans & Credit   0.637898       2.0     High
# 35    BR036      Erode - Wealth Management   0.598447       3.0     High
# 44    BR045       Chennai - Forex/Treasury   0.560670       4.0     High
# 17    BR018        Vellore - Retail Branch   0.547570       5.0     High
# 28    BR029  Bangalore - Corporate Banking   0.537638       6.0     High
# 20    BR021       Chennai - Loans & Credit   0.508195       7.0     High
# 9     BR010        Delhi - Digital Banking   0.447856       8.0   Medium
# 13    BR014   Tirunelveli - Loans & Credit   0.446548       9.0   Medium
# 42    BR043     Trichy - Corporate Banking   0.439568      10.0   Medium
# 34    BR035    Madurai - Corporate Banking   0.438994      11.0   Medium
# 11    BR012         Mumbai - Retail Branch   0.431176      12.0   Medium
# ...
